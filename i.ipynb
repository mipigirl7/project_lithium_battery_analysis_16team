# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import math
import matplotlib.pyplot as plt
import matplotlib as mpl
import platform
import ast

df= pd.read_csv("rti_cycle_detail.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2794 entries, 0 to 2793
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   battery_id                2794 non-null   str
#  1   group                     2794 non-null   str
#  2   analysis_role             2794 non-null   str
#  3   start_time                2794 non-null   str
#  4   filename                  2794 non-null   str
#  5   cycle                     2794 non-null   float64
#  6   discharge_cycle_raw       2794 non-null   int64
#  7   discharge_cycle_valid     2746 non-null   float64
#  8   capacity_ah               2769 non-null   float64
#  9   soh                       2553 non-null   float64
#  10  eol_soh_threshold         2694 non-null   float64
#  11  eol_cycle                 2282 non-null   float64
#  12  rul_current_row           2282 non-null   float64
#  13  rul_label_type            2794 non-null   str
#  14  re_last                   2718 non-null   float64
#  15  rct_last                  2718 non-null   float64
#  16  temperature               2794 non-null   int64
#  17  cap_anomaly               2794 non-null   bool
#  18  is_hard_excluded          2794 non-null   bool
#  19  current_capacity_ah       2744 non-null   float64
#  20  current_soh               2585 non-null   float64
#  21  current_rul               2282 non-null   float64
#  22  status                    2794 non-null   str
#  23  status_reason             2794 non-null   str
#  24  return_ready              2794 non-null   str
#  25  recent_soh_slope          2769 non-null   float64
#  26  recent_capacity_slope     2769 non-null   float64
#  27  rul_available             2794 non-null   int64
#  28  rul_note                  2794 non-null   str
#  29  predicted_eol_cycle_like  2282 non-null   float64
#  30  is_latest                 2794 non-null   int64
# dtypes: bool(2), float64(15), int64(4), str(10)
# memory usage: 638.6 KB

# %%
df.groupby('battery_id')['rul_current_row'].max()
# Out:
# battery_id
# B0005    124.0
# B0006    108.0
# B0007      NaN
# B0018     96.0
# B0025      NaN
# B0026      5.0
# B0027      NaN
# B0028      NaN
# B0029      NaN
# B0030      NaN
# B0031      NaN
# B0032      NaN
# B0033      1.0
# B0034      0.0
# B0036      0.0
# B0038      0.0
# B0039      1.0
# B0040      0.0
# B0041     42.0
# B0042    103.0
# B0043    101.0
# B0044     96.0
# B0045      0.0
# B0046     16.0
# B0047     10.0
# B0048     11.0
# B0049      NaN
# B0050      NaN
# B0051      NaN
# B0052      NaN
# B0053      0.0
# B0054      0.0
# B0055      0.0
# B0056      0.0
# Name: rul_current_row, dtype: float64

# %%
df['rul_current_row'].isna().sum()
# Out:
# np.int64(512)
